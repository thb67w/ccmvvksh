# %% [markdown]
# <a href="https://colab.research.google.com/github/thb67w/ccmvvksh/blob/master/Python_101_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Functionss.

def greetings(name, age=34):
  #print('hello ' + name + ' !' + ' you are ' + age + ' !')
  print(f'hello {name} ! you are {age} !')

#greetings('Vivek', '34')
greetings('Vivek', 34)
greetings('Vivek')
name = input('Input your name : ')
def greeting(name, age=28, color='red'):
    # Greets user with 'name' from 'input box' and 'age', if available, default age is used
    print("Hello", name, "you are", age, "years old and your favorite color is", color)
    print('Hello '  +  name.capitalize() + ', you will be ' + str(age+1) +'!')
    print(f'Hello {name.capitalize()}, you will be {age+1}! old on your next birthday')
    print('We hear you like the color ' + color.lower() + '!')

name = input('Enter your name: ')
age = input('Enter your age: ')
color = input('Enter your liking color: ')

greeting(name, 32, color.lower())
# 1. Add new print statement - on a new line
#    which says 'We hear you like the color xxx! xxx is a string with color
# 2. extend the function with another  input parameter 'color', that defaults to 'red'
# 3. Capture the color via an input box as variable:color
# 4. Change the 'You are xx!' text to say 'you will be xx+1 years old next birthday
#  adding 1 to the age
# 5. Capitalize first letter of the 'name', and rest are small caps
# 6. Favorite color should be in lowercase



def greeting(name, age=28, color="red"):
 #Greets user with “name” from “input box” and “age”, if available, default age is used
   print(f"Hello {name.capitalize()}, you will be {age+1} next birthday!")
   print(f"We hear you like the color {color.lower()}!")

greeting("brian", 27,"Blue")
greeting(age=27,  color='blue', name='brian')



#Return functions....
def value_added_tax(amount):
    tax = amount * 0.25
    total_amt = amount * 1.25
    return f'{tax}, {total_amt}, {amount}'

price = value_added_tax(100)
print(price, type(price))


#Comparison ..Operators....

a=7
b=3
c='john'
d='john'
print('a == b is', a == b)
print('a != b is', a != b)
print('a > b is', a > b)
print('a < b is', a < b)
print('a >= b is', a >= b)
print('a <= b is', a <= b)
print('o in John is ','o' in 'John') #membership
print('o not in John is ','o' not in 'John') #non membership
print('John is John ',c is d) #identity
print('John is not John is ',c is not d) # negative identity

a = [3,7,42]
b = [3,7,42]
print(a == b)
print(a is b)
print(id(a), id(b))

print(int(True))
print(int(False))

print(bool('paarot')) #evaluates to True
print(bool(1))  #evaluates to True
print(bool(44)) #evaluates to True
print(bool('')) #evaluates to False
print(bool(' ')) #evaluates to True
print(bool(0)) #evaluates to False
print(42 + True) #evaluates to 43
print(42 + False) #evaluates to 42

is_raining = False
is_cold = False
print("Good Morning")
if is_raining and is_cold:
    print("Bring Umbrella and jacket")
elif is_raining and not(is_cold):
    print("Bring Umbrella")
elif not(is_raining) and is_cold:
    print("Bring jacket")
else:
    print("Shirt is fine..")


amount = 51
if(amount <= 50):
  print('Purchase approved')
else:
  print('Enter PIN ..')


print('if elif else - Exercise')
# Create a calculator which handles +,-,*,/ and outputs answer based on the mode/ operator used
# Hint: use 3 separate inputs
# Bonus: Extend functionality with extra mode so it also does celsius to fahrenheit conversion
# formula is: temp in C*9/5 + 32 = temp in f

mode = input('Enter the opertion +/-// or f to convert Cel to farenheit: ')
val1 = (int)(input('Enter Val1 = '))

if (mode.lower() == 'f'):
  print(f'Farenheit Temp = {(val1 * 9/5) + 32}')
else:
  val2 = (int)(input('Enter Val2 = '))

  if (mode == '+'):
    print(f'Output = {val1 + val2}')
  elif (mode == '-'):
    print(f'Output = {val1 - val2}')
  elif (mode == '*'):
    print(f'Output = {val1 * val2}')
  elif (mode == '/'):
    print(f'Output = {val1 / val2}')
  else :
    print('Input Error !!')


def num_days(month):
    days=31
    if month in ('apr', 'jun', 'sep', 'nov'): #can use list, set aass well
        days=30
    elif month == 'feb':
        days=28
    print('number of days in',month,'is',days)

num_days('sep')
# optimize/shorten the code in the function
# try to reduce the number of conditionals


#While Loop....
print("1.*Loops are great*")
print("2.**Loops are great**")
print("3.***Loops are great***")
print("4.****Loops are great****")
print("5.*****Loops are great*****")

i=0
while(i<5):
  i+=1
  print(f"{i}." + i*"*" + "Loops are great" + i*"*")


# Three Loop Questions:
#1. What do I want to repeat?
#  -> message
#2. What do I want to change each time?
#  -> stars
#3. How long should we repeat?
#  -> 5 times


print('Guessing game')
# Guess the correct number in 3 guesses. If you don’t get it right after 3 guesses you lose the game.
# Give user input box: 1. To capture guesses,
# print(and input boxes) 1. If user wins 2. If user loses
# Tip:( remember you won’t see  print statements durng execution, so If you want to see prints during whle loop, then print to the input box

num = 12
guess = 0
guess_limit=3
guess_number = 0

while guess_number < guess_limit:
    guess = int(input(f'Guess # {guess_number} a number 1-20: last guess:{guess} '))
    if guess == num:
        print(f'You Win! You Guessed it: {guess}')
        break
    else:
        print(f'No, not {guess}!')
        guess_number += 1
if guess != num:
    print(f'Sorry you lose! It was {num}')




#Modification 1: number 1-100, tell user if guess is too high/low ,and let them have 5-10 guesses.
# Tip:( remember you won’t see  print statements during execution, so If you want to see prints during whle loop, print to the input box (This is specific to this platform)
# Three Loop Questions:
#1. What do I want to repeat?
#  ->
#2. What do I want to change each time?
#  ->
#3. How long should we repeat?
#  ->
num = 76
guess = 0
guess_limit=5
guess_number = 0
guess = int(input(f'Guess a number 1-100: '))
guess_number +=1
while guess_number < guess_limit:

    if guess != num:
        guess_number +=1
        if guess > num:
            guess = int(input(f'{guess} Too high - Guess again 1-100: '))
        else:
            guess = int(input(f'{guess} too low - Guess again 1-100: '))
    if guess == num:
        print(f'You Win! You Guessed it: {guess}')
        break

if guess != num:
    print(f'Sorry you lose! It was {num}')



#For loop...

for furgle in 'Norwegian blue':
    print(furgle)

print("For Loop done!")

for furgle in range(2, 8, 2):
    print(furgle)

print("For Loop done!")

for name in ['John','Terry','Eric','Michael','George']:
    print(name)

print("For Loop done!")

friends = ['John','Terry','Eric','Michael','George']
#for friend in friends:
for index in range(len(friends)):
    print(friends[index])

print("For Loop done!")


friends = ['John','Terry','Eric','Michael','George']
for friend in friends:
    if friend == 'Eric':
        print('Found ' + friend + '!')
        break #continue
    print(friend)

friends = ['John','Terry','Eric']
for friend in friends:
    for number in [1,2,3]:
        print(friend, number)

print("For Loop done!")


names=['piyush', 'akshay', 'mudit' ]
names1=['jappu', 'nitin', 'kapil']
msg = 'You are invited to the party on saturday.'
names1.extend(names)

for index in range(2):
  names1.append(input('Extra name to invite into party: '))

for j in names1:
  print(f'{j.capitalize()} {msg.capitalize()}')


print('python101 - Enumerate')
friends = ['Brian', 'Judith', 'Reg', 'Loretta', 'Colin']
efriends = [(51,'Brian'), (52,'Judith'), (53,'Reg'), (54,'Loretta'), (55,'Colin')]

#i = 51
#for friend in friends:
#    print(i, friend)
#    i = i +1 # += 1
for num, friend in enumerate(friends,51):
    print(num, friend)
for friend in enumerate(friends,51):
    print(friend)
for friend in enumerate(enumerate(friends,51),-100):
    print(friend)
for num, letter in enumerate('python',start = 5):
    print(num, letter)
print(type(enumerate(friends)))
print(list(enumerate(friends)))





my_list = [1,5,3,7,2] #mutable
my_dict = {'car':4,'dog':2,'add':3,'bee':1}
my_tuple = ('d','c','e','a','b') #unmutable
my_string = 'python' #unmutable

print(my_list,'original')
print(my_list.sort())
print(my_list,'new')
print(my_list.reverse())
print(my_list,'new')
print(sorted(my_list))
print(list(reversed(my_list)))
print(my_list[::-1])
my_list = [1,5,-3,7,-2]
my_llist=[['car',4,65],['dog',2,30],['add',3,10],['bee',1,24]]
#print(sorted(my_list), key=abs) #printss the abolute value in sortedd
print(sorted(my_llist, key=lambda item : item[0]))
print(sorted(my_llist, key=lambda item : item[1]))
print(sorted(my_llist, key=lambda item : item[2]))


print(my_tuple,'original')
print(sorted(my_tuple))
print(my_tuple,'new')

print(my_string,'original')
print(sorted(my_string))
print(my_string,'new')

print(my_dict,'original')
print(sorted(my_dict.items()))
print(sorted(my_dict.values()))
print(sorted(my_dict.values(), reverse=True))
print(my_dict,'new')



movie = {
    'title' : 'Life of Brian',
    'year' : 1979,
    'cast' : ['John','Eric','Michael','George','Terry']
}
print(movie)
print(movie['title'])
print(movie.get('budget','not found'))

movie = {
    'title' : 'Life of Brian',
    'year' : 1979,
    'cast' : ['John','Eric','Michael','George','Terry']
}
movie['title'] = 'The Holy Grail'
#movie.update({'title' : 'The Holy Grail','year':1975,'cast':['John','Eric','Michael','George','Terry']})
print(movie.get('title'))
movie['budget'] = 250000
print(movie.get('budget'))
year = movie.pop('year')
print(year)
#del movie['year']
print(movie.keys())
print(movie.values())
print(movie.items())

for key, value in movie.items():
  print(key, value)


python = {'John':35,'Eric':36,'Michael':35,'Terry':38,'Graham':37,'TerryG':34}
holy_grail = {'Arthur':40,'Galahad':35,'Lancelot':39,'Knight of NI':40, 'Zoot':17}
life_of_brian = {'Brian':33,'Reg':35,'Stan/Loretta':32,'Biccus Diccus':45}
#membership test
print('Arthur' in holy_grail)
if 'Arthur' not in python:
    print('He\'s not here!')

people = {}
people1 = {}
people2 = {}
#method 1 update
people.update(python)
people.update(holy_grail)
people.update(life_of_brian)
print(sorted(people.items()))

#method 2 comprehension
for groups in (python,holy_grail,life_of_brian) : people1.update(groups)
print(sorted(people1.items()))

#method 3 unpacking 3.5 later
people2 = {**python,**holy_grail,**life_of_brian}
print(sorted(people2.items()))
print('The sum of the ages: ', sum(people.values()))

#It’s...not really an adventure game...
#Ver 1.0
#Your village is being attacked by 'a germanic tribe' and you need to run to the stores and get the right things to save your village,
#and probably some good looking girl or boy you want to marry. All prices in gold pieces excl. VAT... chop chop!! ze germanz are coming!
#The code should allow you to get 1 thing from each store and each item you get should be removed from the store inventory, then do same for next store...
# one way to buy by typing the key 'newt' in an input box...or something
# at end you should print the 'items' you have taken..in this version you don't have to pay for stuff or add it up
#ver 1.2 add ability to exit a store without buying and go to next by typing 'exit', and to exit if a nonexistant item is bought(typed)
#Add purse with 1000 gold pieces and payment for the items during or at end of code and show a message about total cost and how much gold you have left
#ver 1.4 random bug fix, ' browser compatability', refactoring code... basically being lazy ..stop scrolling TikTok/Facebook! ;-)
#Ver 1.5 print inventory before and after purchases as one department_store of stuff(combine inventories from all stores into one...pretend Big Biz bought all the local stores, and want constant reporting for inventory management...)
# as in all games there is a special way to do this that actually makes money and solves the problem...can you find 'them'? Do you know why? May require knowledge of actual python 'lore'

#create stores
freelancers = {'name':'freelancing shop','brian': 70, 'black knight':20, 'biccus diccus':100, 'grim reaper':500, 'minstrel':-15}
antiques = {'name':'Antique Shop','french castle':400, 'wooden grail':3, 'scythe':150, 'catapult':75, 'german joke':5}
pet_shop = {'name':'Pet Shop','blue parrot':10, 'white rabbit':5, 'newt': 2}

cart = {}
purse = 1000
buy_items = {}
buy_items1 = ''
#morning inventory
department_store = {}

for department in (freelancers, antiques, pet_shop) :department_store.update(department)
print('Morning inventory of stores', sorted(department_store.items()))
print('-----------------')

print(f'you have {purse} gold pieces in your purse')
for shop in (freelancers, antiques, pet_shop):
  print(f'Welcome to shop {shop["name"]}')
  buy_item = input(f'Select the items {shop} .... ').lower()
  if buy_item in shop:
    buy_items1 = buy_items1 + f'{buy_item}:{shop[buy_item]} Gp, '
    cart.update({buy_item:shop.pop(buy_item)})
    buy_items = ", ".join(list(cart.keys()))
  else: exit()

print(f'You Purchased {buy_items1}')
print(f'you brought {sum(cart.values())} have left with {purse - sum(cart.values())} gold pieces')

#evening inventory
department_store_after = {**freelancers, **antiques, **pet_shop} #pyth 3.5
print('-----------------')
print('Evening inventory of stores', sorted(department_store_after.items()))


##File Handdling
